# %%
from typing import Annotated, Literal, TypedDict, Any
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage
from langchain_core.tools import tool
import pandas as pd
import pickle
from tqdm import tqdm
import os
import json
from langchain_core.documents import Document
from pydantic import Field, BaseModel
import pickle
from langchain_openai import ChatOpenAI
class MedicalAskContent(BaseModel):
    
    disease: list[str] = Field(
        default_factory=list,
        description="医生提问中的疾病对象"
    )
    symptom: list[str] = Field(
        default_factory=list,
        description="医生提问中的症状对象"
    )
    medcine: list[str] = Field(
        default_factory=list,
        description="医生提问中的药物对象"
    )
    surgery: list[str] = Field(
        default_factory=list,
        description="医生提问中的手术对象"
    )
    body_part: list[str] = Field(
        default_factory=list,
        description="医生提问中的身体部位对象"
    )
    medical_check: list[str] = Field(
        default_factory=list,
        description="医生提问中的检查项目对象"
    )
    concept: list[str] = Field(
        default_factory=list,
        description="医生提问中的问诊医学概念对象"
    )
class RetrievalAction(BaseModel):
    """The action of retrievaling from the knowledge base."""
    reasoning: str = Field(
        description="The reasong why you are doing the following query."
    )
    queries: list[str] = Field(description="The list of queries to execute. Each should be a question.")

class RetrievalItem(TypedDict):
    
    query: str
    refined_result: str

class AskAction(BaseModel):
    """The action of asking the patient for extra information."""
    reasoning: str = Field(
        description="The reason why you are asking the following question."
    )
    disease: list[str] = Field(
        default_factory=list,
        description="你提问的疾病对象"
    )
    symptom: list[str] = Field(
        default_factory=list,
        description="你提问的症状对象"
    )
    medcine: list[str] = Field(
        default_factory=list,
        description="你提问的药物对象"
    )
    surgery: list[str] = Field(
        default_factory=list,
        description="你提问的手术对象"
    )
    body_part: list[str] = Field(
        default_factory=list,
        description="你提问的身体部位对象"
    )
    medical_check: list[str] = Field(
        default_factory=list,
        description="你提问的检查项目对象"
    )
    concept: list[str] = Field(
        default_factory=list,
        description="你提问的问诊医学概念对象"
    )
    text: str = Field(
        description="The text sent to the patient."
    )

class TellAction(BaseModel):
    """The action of telling the patient something."""
    reasoning: str = Field(
        description="The reason why you are telling the user the following text."
    )
    text: str = Field(
        description="The text sent to the patient."
    )

class Conversation(TypedDict):
    
    patient: str
    doctor: str

class RagMeta(TypedDict):

    vector_store: list[Document]
    baidu_search: tuple[
        Annotated[str, "question"],
        Annotated[str, "answer"],
        Annotated[str, "failed"],
        Annotated[str, "src"]
    ]

class RetrievalRequest(BaseModel):

    reasoning: str = Field(
        description="The process of how you arrived on the following queries you are going to make based on the input. Reasoning should be concise and contain only important points."
    )
    queries: list[str] = Field(
        description="The queries you want to make. Each should be a question."
    )

class RefinedResult(BaseModel):

    refined_result: str = Field(
        description="The refined result of the given message. Should be in no more than 2 to 3 sentences. Should contain no more content than what's related to the query."
    )

class ReasoningCheck(BaseModel):

    reasoning: str = Field(
        description="The reason why you assert that you can deduce the answer of the professional doctor from the given information, or why you cannot deduce it. Reasoning should be concise and contain only important points."
    )
    deducible: bool = Field(description="Whether you can deduce the answer of the professional doctor from the given information.")

class Response(BaseModel):

    reasoning: str = Field(
        description="The reason why you ask the user for more information or respond to them. Reasoning should be concise and contain only important points."
    )
    is_asking: bool = Field(
        description="Wehther your sentence asks the user for more information or tell them something. If this is true, this response will be marked as ask, or else it will be marked as tell."
    )
    entities: list[str] = Field(
        description="The medical entities related to this conversation. Only the important ones should be included."
    )
    text: str = Field(
        description="The text sent to the patient."
    )

class RetrievalItem(TypedDict):
    
    query: str
    refined_result: str

class StructuredOutputWithRaw(TypedDict):
    
    raw: AIMessage
    parsed: Any
    parsing_error: Any

# %%
lded = pickle.load(open(
    "./lora_sft_zh_med_ask_records.pkl", "rb"
))

# %%
import Levenshtein

# %%
rr = 0

# %%
def flatten_medical_ask_content(i: MedicalAskContent) -> str:
    return f"{''.join(i.disease)}{''.join(i.symptom)} {''.join(i.medcine)}{''.join(i.surgery)}{''.join(i.body_part)}{''.join(i.medical_check)}{''.join(i.concept)}"

# %%
cnt = 0

# %%
for each in lded:
    try:
        model_out = each
        model_entities = MedicalAskContent(
            disease=model_out[2].disease,
            symptom=model_out[2].symptom,
            medcine=model_out[2].medcine,
            surgery=model_out[2].surgery,
            body_part=model_out[2].body_part,
            medical_check=model_out[2].medical_check,
            concept=model_out[2].concept,
        )
        r = Levenshtein.ratio(
            flatten_medical_ask_content(each[0]['all_meta']['doc_objs']),
            flatten_medical_ask_content(model_entities),
        )
        if r > 0.3:
            print(model_entities)
            print(each[2].text)
            print(each[0]['all_meta']['doc_objs'])
            print(each[0]['all_meta']['doc_ask_sentence'])
    except:
        continue
# Out:
# disease=[] symptom=['疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '食物', '疼痛性质']
# 请问您在吃东西时是否注意到特定类型的食物会引起更多的疼痛？此外，您的饮食习惯最近是否有改变？
# disease=[] symptom=['疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 可以分清左右和上下疼痛么？
# disease=[] symptom=['腹痛', '头晕', '乏力'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间', '伴随症状']
# 为了更好地理解您的状况，请您告诉我您是否有其他伴随症状，比如腹痛、头晕、乏力等？此外，您最近的月经周期是否正常？这些信息将有助于我们判断您的情况。
# disease=[] symptom=['腰酸', '乏力'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 腰酸乏力明显吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您能详细描述一下您不清楚的具体内容吗？这样我可以更好地理解您的情况并提供帮助。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=['检查'] concept=[]
# 做过检查吗？
# disease=[] symptom=['头痛', '恶心', '呕吐', '视力模糊'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['压力', '情绪波动', '睡眠质量', '其他不适症状']
# 为了更好地理解您的情况，您能否描述一下头痛的频率？是否伴随有恶心、呕吐或视力模糊等症状？另外，您最近是否有经历过较大的压力或情绪波动？以及您的睡眠质量如何？这些信息将有助于我们更准确地判断您的状况。
# disease=[] symptom=['头痛', '恶心', '呕吐', '发热', '畏光', '畏声'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您头痛时有没有恶心，呕吐？有没有发热？有没有畏光，畏声？
# disease=[] symptom=['发烧', '口腔溃疡'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 手上长小红点可能是多种原因造成的，包括手足口病等。为了更好地帮助您，我想了解一下孩子是否有发烧、口腔溃疡等其他症状？这样我可以为您提供更合适的建议。
# disease=[] symptom=['发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 孩子发热不？
# disease=[] symptom=['发热', '呕吐'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地理解您孩子的状况，您能否提供更多信息？例如，孩子是否有其他症状，比如发热或呕吐？此外，孩子的饮食中最近是否有新的食物或药物？
# disease=[] symptom=['发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 宝贝发热吗？
# disease=[] symptom=['黄色颗粒', '红肿', '视力变化'] medcine=[] surgery=[] body_part=['眼睛'] medical_check=[] concept=[]
# 请问您这些症状持续了多久？有没有其他症状，比如眼睛红肿或视力变化？
# disease=[] symptom=['颗粒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 颗粒在哪里？
# disease=[] symptom=['疼痛', '乳房肿胀', '皮肤变化', '乳头溢液'] medcine=[] surgery=[] body_part=['乳房'] medical_check=[] concept=['疼痛程度', '持续时间', '其他症状']
# 请问您能详细描述一下您的疼痛吗？例如，疼痛的程度、持续时间，以及是否有其他症状，比如乳房肿胀、皮肤变化或乳头溢液等？这些信息将有助于我们更好地理解您的情况并提供建议。
# disease=[] symptom=['乳房胀痛', '乳头溢液'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 经前乳房胀痛明显吗？乳头有溢液吗？
# disease=[] symptom=['疼痛', '肿胀', '麻木', '刺痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您的腿疼是持续性的还是间歇性的？疼痛的性质是钝痛、锐痛还是抽筋？您是否还有其他症状，例如肿胀、麻木或刺痛？这些信息将帮助我更好地理解您的情况。
# disease=[] symptom=['疼痛', '肿胀'] medcine=[] surgery=[] body_part=['腰背部'] medical_check=[] concept=[]
# 有没腰背部疼痛，肿胀？
# disease=[] symptom=['疼痛', '视力变化'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['家族病史']
# 为了更好地帮助您，请提供更多信息，例如您是否有其他症状（如疼痛、视力变化等），或者您的家族中是否有人有类似的眼部问题。
# disease=[] symptom=['红肿', '疼痛'] medcine=[] surgery=[] body_part=['眼球'] medical_check=[] concept=[]
# 眼球是否红肿疼痛？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '生活压力', '其他症状']
# 下巴红肿可能由多种因素引起，包括情绪波动和饮食习惯。请问您最近的饮食习惯如何？是否有其他症状或生活压力？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况']
# 平时饮食是什么。
# disease=[] symptom=['身体不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['术后恢复时间']
# 请问您在术后恢复了多长时间？目前是否有任何身体不适或症状？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['时间']
# 多久时间
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活习惯', '压力源', '情绪变化']
# 您提到在观看与性有关的内容时会有勃起反应，但在手淫时却无法勃起。请问您是否有其他相关的症状，比如压力源、情绪变化或是生活习惯的变化？这将有助于我更好地理解您的情况。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['性别', '性生活']
# 你现在有性对象？有性生活？
# disease=[] symptom=['咳嗽', '喉咙痛', '鼻塞', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地了解您的情况，请问您除了咳嗽之外，还有其他症状吗？例如，喉咙痛、鼻塞、发热等？
# disease=[] symptom=['咳嗽'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['白天', '晚上']
# 是白天咳嗽还是晚上？
# disease=[] symptom=['腹痛', '恶心', '呕吐'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '伴随症状']
# 为了更好地理解您的情况，请您告诉我您最近的饮食习惯以及是否有其他伴随症状，比如腹痛、恶心或呕吐等？
# disease=[] symptom=['吐酸水', '烧心', '恶心', '干呕'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 会吐酸水烧心吗？会恶心干呕吗？
# disease=[] symptom=['瘙痒', '疼痛', '红疹'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 关于您外阴的异常症状，能否描述一下具体的症状，比如是否有瘙痒、疼痛、红疹等情况？这将帮助我更好地理解您的情况，并提供建议。
# disease=[] symptom=['痛', '瘙痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 你这皮疹痛吗？瘙痒吗？
# disease=[] symptom=['症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间', '伴随症状', '既往心脏病史']
# 为了更好地理解您的状况，请您提供更多信息，例如这些症状持续了多长时间？是否伴有其他症状？您是否有既往的心脏病史？
# disease=[] symptom=['心慌'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['时间', '如何慌', '其它相关症状']
# 要说清心慌特点，时间，如何慌？还有其它相关症状吗？
# disease=[] symptom=['症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 结缔组织病是一组涉及结缔组织的疾病，常见的症状包括多关节炎、多关节痛、发热、四肢无力和呼吸困难等。治疗方法通常包括药物治疗和中药治疗，具体方案需遵循医生指导。此外，结缔组织病包括多种类型，如红斑狼疮、硬皮病、皮肌炎和类风湿性关节炎等。请问您是否有具体的症状或想要了解的方面？
# disease=[] symptom=[] medcine=['用药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 请告知目前用药具体情况。
# disease=[] symptom=['疼痛', '刺痛感', '麻木'] medcine=[] surgery=[] body_part=['手'] medical_check=[] concept=['伴随症状', '手部活动受限']
# 为了更好地理解您的手麻情况，请您告诉我，在手麻发生之前，是否有过其他不适的症状，比如疼痛、刺痛感或者手部活动受限？另外，您是否有过类似的情况或者其他健康问题？
# disease=[] symptom=['麻'] medcine=[] surgery=[] body_part=['手', '手指', '手掌'] medical_check=[] concept=[]
# 哪个手？是单个的手指还是全部的手掌？是早晨睡觉醒来麻还是一天持续的麻？
# disease=[] symptom=['咳嗽', '咳痰', '发热', '呼吸困难'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您的咳嗽持续了多长时间？是否有伴随其他症状，比如咳痰、发热或者呼吸困难？
# disease=[] symptom=['咳嗽'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 夜里咳嗽还是白天咳嗽厉害？
# disease=[] symptom=['分泌物', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['伴随症状', '性伴侣', '健康问题']
# 根据您的描述，您可能遇到了一些与龟头和阴茎相关的症状。珍珠疹通常表现为无害的小颗粒，而阴茎疼痛和灼热感可能由多种原因引起，包括尿道炎、包皮内感染等。为了更好地帮助您，我需要了解更多信息，例如您是否有其他伴随症状（如分泌物、不适等），或者您最近是否有过性伴侣或相关健康问题。请您提供更多的细节，以便我能更准确地评估您的情况。
# disease=[] symptom=['分泌物'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 小便有分泌物吗？
# disease=[] symptom=['疼痛', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['其他症状', '最近的变化']
# 您好！您提到牙齿上有一道小小的裂缝，这可能会导致细菌进入牙齿内部，影响美观和咀嚼功能。为了更好地帮助您，请问您是否有其他症状，比如疼痛或者不适？此外，您最近是否有过任何变化，比如饮食习惯或口腔卫生习惯？
# disease=[] symptom=['冷热疼痛', '咬合不适'] medcine=[] surgery=[] body_part=['牙齿'] medical_check=[] concept=[]
# 牙齿有症状吗？比如有没有冷热疼痛，咬合不适的情况？
# disease=[] symptom=['发热', '咳嗽加重', '喉咙痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 感冒的常见症状包括流鼻涕、打喷嚏、鼻塞、喉咙痛和咳嗽。白加黑和感康主要用于缓解感冒引起的发热、头痛和鼻塞等症状。如果您已经尝试了这两种药物，但症状仍然没有改善，建议您考虑其他药物，例如对乙酰氨基酚、伪麻黄碱盐酸盐或抗组胺药物。请问您是否有其他症状，比如发热、咳嗽加重或喉咙痛？这将有助于我为您提供更好的建议。
# disease=[] symptom=['发烧'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 什么症状呢？发烧吗？
# disease=[] symptom=[] medcine=[] surgery=['手术'] body_part=[] medical_check=[] concept=['恢复时间', '相关问题']
# 我们医院确实提供手术服务，并且有多种手术类型可供选择。术后恢复时间因手术类型和个人差异而异，通常在7-10天左右。请问您对手术有什么具体的问题或者需求吗？
# disease=[] symptom=[] medcine=[] surgery=['手术'] body_part=[] medical_check=[] concept=[]
# 什么手术？
# disease=[] symptom=['发热', '腹痛', '呕吐'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况', '吃了什么食物']
# 为了更好地帮助您，请问您最近有没有感到发热、腹痛或者呕吐？此外，您最近的饮食有什么特别的变化吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况', '大便', '伴随症状']
# 吃的怎么样？大便会很稀吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['症状', '影响', '治疗方法']
# 脑缺氧后遗症可能会导致记忆力下降、智力下降、学习困难等症状，严重影响生活质量。针对出生时脑缺氧的后遗症，建议尽早进行系统的康复训练，并定期随访。请问您是否有具体的症状或者影响您生活的情况？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['后遗症']
# 孩子是哪一种后遗症？
# disease=[] symptom=['疼痛', '发热', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您提到的乳晕上的包块在不同时间有不同的变化。请问这个包块是否有疼痛感？最近是否伴随发热或其他不适？这些信息将有助于进一步评估您的情况。
# disease=[] symptom=['疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 疼痛不呢。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['病理报告']
# 关于您提到的纵隔底度恶性软骨粘液样纤维瘤，手术后的病理诊断非常重要。请问您的病理报告中是否有具体的诊断结果？此外，您是否有任何具体的症状或担忧？这将帮助我为您提供更准确的建议。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 你有什么问题？
# disease=[] symptom=['疼痛', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['口腔卫生习惯', '饮食习惯']
# 您好！根据您的描述，嘴巴张大时骨头响可能是由于颞颌关节功能紊乱引起的，这通常与拔牙、饮食习惯或精神压力等因素有关。而唱歌时闻到臭味可能与口腔卫生不佳有关，例如牙齿问题或消化系统问题。为了更好地帮助您，我想了解一下您是否有其他相关症状，比如疼痛或其他不适？另外，您平时的口腔卫生习惯和饮食习惯如何？
# disease=[] symptom=['局部疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 局部疼痛吗。
# disease=[] symptom=['疼痛', '分泌物', '视力模糊'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['游泳时佩戴护目镜']
# 为了更好地理解您的情况，请您告诉我更多关于您眼睛的症状的信息，比如是否有疼痛、分泌物、视力模糊，或者您在游泳时是否佩戴了护目镜？这些信息将帮助我为您提供更准确的建议。
# disease=[] symptom=['分泌物'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有分泌物呢？
# disease=[] symptom=['发热', '口腔内溃疡'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活习惯', '饮食', '伴随症状']
# 为了更好地帮助您，请问您最近的生活习惯和饮食如何？是否有其他伴随症状，比如发热或口腔内溃疡？
# disease=[] symptom=['发热', '其他症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有发热？还有没有其他症状？
# disease=[] symptom=['疲倦', '体重变化'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['情绪状态', '疲倦', '体重变化']
# 为了更好地帮助您，请问您最近的情绪状态如何？是否有感到疲倦或者体重变化的情况？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['体重']
# 体重有无变化？
# disease=[] symptom=['耳痛', '头晕', '听力变化'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地理解您的症状，您能否描述一下耳鸣和耳闷发生的频率、持续时间，以及是否伴随有其他症状，比如耳痛、头晕或听力变化？
# disease=[] symptom=['耳闷'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有耳闷？
# disease=[] symptom=['胃疼', '恶心', '呕吐', '体重变化'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间', '伴随症状', '饮食习惯']
# 为了更好地帮助您，请您提供更多信息，例如您的胃疼持续了多长时间？有没有其他伴随症状，比如恶心、呕吐或体重变化？同时，您最近的饮食习惯是否有改变？
# disease=[] symptom=['腹痛', '呕吐'] medcine=[] surgery=[] body_part=['腹部'] medical_check=[] concept=['出现时间', '进食情况']
# 以什么部位为主，是什么时候出现腹痛？以进食后还是饿了的时候开始疼痛？有呕吐没？
# disease=[] symptom=['咳嗽', '发热', '胸痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间']
# 为了更好地理解您的咳嗽情况，请您告诉我是否有其他伴随症状，比如发热、胸痛，或者咳嗽持续了多长时间？
# disease=[] symptom=['咳嗽'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 除了咳嗽还有其他症状吗。
# disease=[] symptom=['疼痛', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['结石大小', '治疗方案']
# 您好！关于您的肾囊肿和尿道结石，尿急和尿频确实可能是结石引起的。为了更好地帮助您，请问您是否有其他症状，比如疼痛、发热等？另外，您对结石的大小有了解吗？这将有助于我们确定合适的治疗方案。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=['肾囊肿大小'] concept=[]
# 肾囊肿大小？
# disease=[] symptom=['疼痛程度', '疼痛性质'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['相关病史', '正在接受治疗']
# 请问您能详细描述一下您的症状吗？例如，疼痛的程度、性质以及是否有其他相关的病史或正在接受的治疗？这些信息将帮助我为您提供更好的建议。
# disease=[] symptom=['疼痛剧烈', '晨起疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['活动后', '时间']
# 您是活动后疼痛剧烈还是晨起疼痛明显呢？
# disease=[] symptom=['小孔', '出血', '分泌物'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 关于您婴儿嘴唇上的血管瘤，颜色变淡可能是正常的恢复过程，但如果出现小孔，这可能表示局部皮肤有所变化。请问您能否提供更多信息，例如小孔的大小、形状以及是否有出血或分泌物？这样我可以更好地帮助您。
# disease=[] symptom=['出血'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有无出血？
# disease=[] symptom=['肿胀', '疼痛', '红肿', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，请问您的肿胀是突然发生的吗？有没有伴随其他症状，比如疼痛、红肿或者发热？
# disease=[] symptom=['肿'] medcine=[] surgery=[] body_part=['腿'] medical_check=[] concept=[]
# 是两条腿都肿？
# disease=[] symptom=['疼痛', '出汗', '恶心', '气短'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地理解您的情况，请您提供更多信息，例如疼痛的具体性质（如刺痛、压榨感）、疼痛的持续时间、是否有其他伴随症状（如出汗、恶心、气短等）。
# disease=['胃不好'] symptom=['疼痛'] medcine=['救心丸'] surgery=[] body_part=[] medical_check=[] concept=[]
# 有过什么疾病吗？比如胃不好？吃救心丸可以缓解吗？疼痛持续了多长时间？
# disease=[] symptom=['疼痛', '排尿困难', '分泌物', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['疼痛的持续时间', '伴随症状']
# 为了更好地理解您的情况，请您提供更多信息，例如疼痛的持续时间、是否有其他伴随症状（如排尿困难、分泌物、发热等），以及最近是否有过性活动或其他相关健康问题。
# disease=[] symptom=['疼痛'] medcine=[] surgery=['手术'] body_part=[] medical_check=[] concept=['多长时间']
# 你做过什么手术？疼痛有多长时间了？有什么诱因吗？
# disease=[] symptom=['其他症状'] medcine=['具体用药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 根据您的描述，脸部病毒感染可能导致急性面神经炎，表现为面部不对称和表情肌肉麻痹。目前您使用的抗病毒药物效果不明显，建议您提供更多信息，例如您正在服用的具体药物名称，以及是否有其他症状出现，这将有助于我们更好地分析您的情况并提出建议。
# disease=[] symptom=[] medcine=['用药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 具体用药有吗？
# disease=[] symptom=['皮肤和眼白发黄', '乏力', '食欲不振'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 脸色发黄可能与肝功能不佳有关，常见的肝炎症状包括皮肤和眼白发黄、乏力和食欲不振。请问您最近是否有其他不适的症状，比如皮肤和眼白发黄、乏力或食欲不振？如果有这些症状，建议尽快就医确诊。
# disease=[] symptom=['眼球黄', '食欲差', '身软乏力'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 眼球黄不黄？有没有食欲差，身软乏力症状？
# disease=[] symptom=['乳房肿块', '疼痛', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！关于您提到的男性乳头大小不一的问题，可能与个体差异有关。如果您对此感到担忧，或者伴随有其他异常症状（如乳房肿块、疼痛等），建议您尽快咨询专业医生进行详细检查。同时，乳头不对称通常不是由触摸直接引起的，可能是由于先天发育差异或哺乳习惯等原因。请问您还有其他症状吗？
# disease=[] symptom=['不舒服'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有感觉不舒服？
# disease=[] symptom=['发热', '瘙痒', '疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏史']
# 为了更好地理解您的情况，您能否告诉我更多关于这些症状的信息？例如，您是否有发热、瘙痒或其他不适的感觉？此外，您最近是否有过任何过敏史？
# disease=[] symptom=['痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 痒吗？
# disease=[] symptom=['其他症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 关于您提到的垂雍体囊肿，手术是否必要取决于囊肿的大小及其是否压迫到周围结构。通常，较小的囊肿可以通过药物控制症状，而较大的囊肿可能需要手术治疗。请问您的孩子是否有其他症状，比如言语困难或吞咽困难？这将有助于我们更好地评估情况。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有照片吗？
# disease=[] symptom=['恶心', '呕吐', '听力下降', '视力模糊'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您是否有其他症状，比如恶心、呕吐、听力下降或者视力模糊？这些信息将有助于我们更好地理解您的情况。
# disease=[] symptom=['呕吐', '眩晕'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 呕吐吗？每次眩晕持续多长时间？
# disease=[] symptom=['腹痛', '腹泻', '便秘'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 大便带血可能由多种原因引起，包括肛裂、痔疮或结肠疾病等。请问您在便后滴血的同时，是否还有其他症状，比如腹痛、腹泻或便秘？这将有助于我们更准确地判断您的情况。
# disease=[] symptom=['大便'] medcine=[] surgery=[] body_part=[] medical_check=['肠镜'] concept=[]
# 近期大便怎么样，做过肠镜吗。
# disease=[] symptom=['眼痛', '视力模糊'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，您能否提供更多信息，例如您最近的视力变化情况、是否有其他症状（如眼痛、视力模糊等）以及您是否有定期进行眼科检查的习惯？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['视力']
# 视力多少？
# disease=[] symptom=['疼痛'] medcine=[] surgery=[] body_part=['部位'] medical_check=[] concept=['频率', '持续时间', '程度']
# 请问您的血压具体是多少？您能描述一下疼痛的具体部位吗？这种疼痛是经常出现还是偶尔发作？同时，您是否有其他相关症状？
# disease=[] symptom=['疼'] medcine=[] surgery=[] body_part=['血管'] medical_check=[] concept=['多长时间了']
# 哪里的血管疼，多长时间了。
# disease=[] symptom=['瘙痒', '干燥'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['治疗', '护理措施']
# 湿疹的症状包括皮肤发红、丘疹、水疱或结痂，并常伴有瘙痒感。它分为急性期（皮损初为密集的粟粒大小丘疹或小水疱）、亚急性期（以小丘疹和鳞屑为主）及慢性期（皮肤增厚、浸润，有剧烈的瘙痒感）。治疗湿疹主要方法包括保湿、局部药物（如激素类和非激素类外用药物）、光疗、口服抗过敏药等。同时，避免接触可能诱发湿疹的物质，保持皮肤清洁干燥，并注意饮食调整也很重要。请问您目前是否有使用任何治疗或护理措施？
# disease=[] symptom=['皮肤瘙痒', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有其他症状吗？比如皮肤瘙痒，发热等。
# disease=[] symptom=['脱皮', '刺痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活习惯', '接触刺激性清洁用品', '其他症状']
# 为了更好地帮助您，请问您最近的生活习惯如何？例如，是否有频繁接触刺激性清洁用品，或者是否有其他症状？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['接触水', '接触碱性物品']
# 是否接触水和碱性物品比较多？
# disease=[] symptom=['瘙痒', '红肿'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['情绪变化']
# 您能否提供更多关于皮疹的信息？例如，皮疹的外观、位置或是否有其他伴随症状（如瘙痒、红肿等）？同时，您最近是否有过情绪变化？
# disease=[] symptom=['红疙瘩'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 身上是否请红疙瘩？
# disease=[] symptom=['视力下降', '黑点', '漂浮物'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到的双眼玻璃体轻度浑浊可能会导致一些症状，比如看到黑点或漂浮物。请问您是否有这些症状？此外，您是否有注意到视力是否有任何变化？这些信息将有助于我们更好地理解您的情况并提供建议。
# disease=[] symptom=['近视'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 你有无近视？
# disease=[] symptom=['牙疼', '头疼'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间', '伴随症状']
# 您好！孕妇牙疼可能导致头疼，通常与牙齿问题、激素变化或饮食习惯有关。为了更好地帮助您，请问您的牙疼和头疼持续了多长时间？有没有其他伴随症状？
# disease=[] symptom=['牙疼'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 牙疼的原因是什么？
# disease=[] symptom=['症状'] medcine=['治疗方案'] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，请问您的孩子目前有哪些具体的症状？以及医生是否已经给出了任何治疗方案？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['NICU', '治疗']
# 那家NICU治疗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '运动情况', '压力', '焦虑']
# 根据您提供的信息，便秘可能与您的饮食、生活方式以及情绪状态有关。为了更好地帮助您，我想了解一下您在安徽的生活饮食习惯和运动情况，以及您是否有感到压力或焦虑的情况。
# disease=['压力焦虑症'] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 是否有压力焦虑症
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '睡眠质量', '压力源']
# 感谢你分享这些信息！为了更好地帮助你，我想了解一下你最近的饮食习惯和睡眠质量如何？此外，你是否有其他的压力源或困扰？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['情绪', '睡眠']
# 你觉得情绪有什么变化吗？晚上睡得好吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['频率', '持续时间', '其他症状', '情绪状态']
# 您提到的昏暗密闭和压抑的环境可能对您的性功能产生了影响。请问这种情况持续了多长时间？您是否有其他症状或情绪变化？这些信息将有助于我们更好地理解您的状况并提供适当的建议。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['发病时间']
# 多久了？
# disease=[] symptom=['头痛', '恶心', '呕吐', '视觉问题'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续性', '间歇性']
# 为了更好地帮助您，请您描述一下您的头痛是持续性的还是间歇性的？此外，您是否有其他症状，例如恶心、呕吐或视觉问题？这些信息将有助于我们更准确地判断您的情况。
# disease=[] symptom=['头痛'] medcine=[] surgery=[] body_part=['头'] medical_check=[] concept=['痛法', '痛的持续时间']
# 头痛具体哪个部位？怎样的痛法？每次痛多长时间？
# disease=[] symptom=['咳嗽', '发热', '食欲不振', '呼吸急促'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，请问宝宝咳嗽持续了多久？有没有伴随发热、食欲不振或者呼吸急促等症状？
# disease=[] symptom=['发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有发热
# disease=[] symptom=['肩部疼痛', '活动受限'] medcine=[] surgery=[] body_part=['肩部'] medical_check=[] concept=[]
# 请问您肩部的具体症状是怎样的？例如，是否有肩部疼痛、活动受限等情况？另外，您的眼外伤具体发生了什么情况？
# disease=[] symptom=['外伤'] medcine=[] surgery=[] body_part=['肩部'] medical_check=[] concept=[]
# 肩部外伤有吗？
# disease=[] symptom=['症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['病情严重程度']
# 关于先天性心脏病患者的手术时机，通常建议在6个月大之后进行手术，以确保婴儿能够更好地承受手术。然而，具体的手术时机还需根据您的病情和症状来决定。请问您是否有具体的症状或病情严重程度？这样我可以为您提供更详细的建议。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['体重']
# 目前体重多少？
# disease=[] symptom=['痒感', '红肿'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到胳膊上有印子，能否描述一下这些印子的颜色、形状以及是否有其他伴随症状（如痒感、红肿等）？此外，您是否有其他的过敏史或者近期接触过可能引起过敏的物质？
# disease=[] symptom=['痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 痒吗？
# disease=[] symptom=['体温', '发热', '腹泻'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到宝宝有感冒、呕吐、鼻子堵塞和哭闹不止的情况。请问宝宝的体温正常吗？有没有其他症状，比如发热或腹泻？这些信息将有助于我们更好地判断宝宝的健康状况。
# disease=['感冒'] symptom=['发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 家里最近大人是否有感冒？是否有发热症状？
# disease=[] symptom=['异味', '不适感'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['白带的量', '质地']
# 您好！您提到的白带发黄可能与念珠菌感染或其他妇科问题有关。为了更好地帮助您，请您提供更多信息，例如白带的具体特征（如是否有异味、量的多少、质地如何）以及是否还有其他不适感？
# disease=[] symptom=['感染'] medcine=[] surgery=[] body_part=[] medical_check=['白带'] concept=[]
# 治疗后复查了白带吗？还有感染吗？
# disease=[] symptom=['其他症状'] medcine=['药物'] surgery=[] body_part=[] medical_check=[] concept=[]
# 我理解您对当前的药物治疗效果不满意。请问您使用的药物是什么？有没有尝试过其他的治疗方法？同时，您是否有其他症状？
# disease=[] symptom=[] medcine=['药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 你都吃过些什么药？
# disease=[] symptom=['其他症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['相关的健康问题']
# 宫颈糜烂可能与多种因素有关，包括多次人工流产、不洁性生活和清洁过度等。主要症状包括白带增多、阴道瘙痒和性交后疼痛。为了更好地帮助您，您能否分享一下您的具体症状或其他相关健康问题？这样我可以为您提供更个性化的建议和信息。
# disease=[] symptom=['症状'] medcine=[] surgery=['手术'] body_part=[] medical_check=[] concept=[]
# 是否需要手术，要看有没有症状！
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活习惯', '心理状态', '症状持续时间']
# 为了更好地帮助您，请您提供更多信息，例如您的生活习惯、最近的心理状态、症状持续了多久等。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['发病时间']
# 这种情况有多长时间了？
# disease=[] symptom=['瘙痒', '红肿'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况', '生活习惯', '伴随症状']
# 您好！关于您下巴和颈部皮肤异常的情况，可能与饮食、内分泌、清洁习惯等因素有关。请问您最近是否有改变饮食或生活习惯？此外，您是否有其他伴随症状，例如瘙痒、红肿等？这样我可以更好地帮助您。
# disease=[] symptom=['瘙痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 是否瘙痒？
# disease=[] symptom=['咳嗽', '喉咙痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏源', '感冒', '变化']
# 为了更好地理解您的情况，请您告诉我最近是否有接触过可能的过敏源（如花粉、尘螨等），或者您是否有其他症状，比如咳嗽、喉咙痛等？此外，您是否最近有过感冒或环境变化？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏原']
# 查过敏原了没有？
# disease=[] symptom=['发热', '咳嗽', '全身不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['症状持续时间']
# 您好！您提到感冒引起了头痛和鼻涕，想了解一下您的症状持续了多久？是否有其他伴随症状，比如发热、咳嗽或全身不适？这些信息将帮助我更好地理解您的情况并提供建议。
# disease=[] symptom=['发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['持续时间']
# 是否发热？持续时间？
# disease=[] symptom=['口腔干燥', '疼痛', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '其他症状']
# 您提到舌头没有舌苔、嘴里发黏和上牙堂脱皮，请问这些症状持续了多久？是否有伴随的其他症状，比如口腔干燥、疼痛或其他不适？同时，您的饮食习惯是怎样的？
# disease=[] symptom=['口腔内唾液多', '眼干'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 口腔内唾液多吗？眼干不？
# disease=[] symptom=['头痛', '发热', '咳嗽', '流鼻涕'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['既往病史', '过敏史']
# 为了更好地理解您的情况，请您告诉我是否有其他伴随症状，例如头痛、发热、咳嗽或流鼻涕？此外，您是否有任何既往病史或过敏史？
# disease=[] symptom=['头痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 头会痛吗？
# disease=[] symptom=['症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['治疗']
# 请问您最近的症状如何？治疗后是否有改善？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 可以雾化，或喷药。
# disease=[] symptom=['耳鸣', '听力下降', '头痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['发作频率', '持续时间', '伴随症状']
# 为了更好地理解您的情况，请您告诉我更多关于您眩晕发作的信息，例如：这种眩晕发作的频率、持续时间，以及是否伴有其他症状，比如耳鸣、听力下降或头痛等？
# disease=[] symptom=['听力下降', '耳鸣'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有听力下降或耳鸣吗？
# disease=[] symptom=['疼痛', '肿胀', '皮肤变化'] medcine=[] surgery=[] body_part=['脚'] medical_check=[] concept=[]
# 您能详细描述一下您的脚部出现了什么症状吗？例如，您是否感到疼痛、肿胀或者有其他皮肤变化？这些信息将有助于我更好地理解您的情况。
# disease=['脚气病'] symptom=['皮疹', '皮肤痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 你有脚气病吗？家里人有脚气吗？皮疹处皮肤痒吗。
# disease=[] symptom=['声音嘶哑', '咳嗽', '喉咙痛', '呼吸困难'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，我想了解一下孩子声音嘶哑的具体时间长度，以及是否有其他症状，比如咳嗽、喉咙痛或者呼吸困难？
# disease=[] symptom=['声音嘶哑'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['孩子', '平时', '大声喊叫']
# 只是声音嘶哑？没有其他症状？孩子是不是平时喜欢大声喊叫？
# disease=[] symptom=['胃疼', '恶心', '呕吐', '腹胀'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地理解您的情况，您能否描述一下胃疼的具体位置、性质（如刺痛、钝痛等），以及心跳加速的频率和持续时间？同时，您是否有其他症状，比如恶心、呕吐或腹胀？
# disease=[] symptom=['嗳气泛酸', '恶心', '呕吐'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有嗳气泛酸，恶心呕吐症状？
# disease=[] symptom=['发热', '疼痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏史']
# 请问您还有其他症状吗？例如，您是否感到发热、疼痛，或者有无过敏史？
# disease=[] symptom=['痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 痛不痛？
# disease=[] symptom=['咳嗽', '胸痛', '呼吸困难', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您的咳嗽是干咳还是有痰？咳嗽的频率如何？是否伴有其他症状，比如胸痛、呼吸困难或者发热？
# disease=[] symptom=['咳嗽', '咳痰', '气紧'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 咳嗽咳痰多吗？是否有咳嗽导致的气紧？
# disease=[] symptom=['疼痛', '胸闷', '呼吸急促'] medcine=[] surgery=[] body_part=['胸部'] medical_check=[] concept=['剧烈运动', '情绪波动']
# 为了更好地理解您的情况，请问您是否有其他症状，比如胸闷、呼吸急促或者在特定情况下（如剧烈运动、情绪波动）是否会加重？此外，您是否有过胸部受伤的经历？
# disease=[] symptom=['痛', '胸闷', '气喘'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 是外面痛还是里边痛？会胸闷气喘吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['癌症类型', '治疗方法']
# 您好！关于您的问题，意外怀孕对胎儿的影响与您老公的癌症类型及其治疗方法密切相关。请您提供更多信息，例如您老公的癌症类型和治疗方法，这样我可以为您提供更准确的建议。
# disease=['癌症'] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 什么癌症
# disease=[] symptom=['红肿', '瘙痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['护肤品', '化妆品']
# 为了更好地帮助您，请问这些小颗粒是否伴有其他症状，比如红肿、瘙痒，或者您最近是否使用了新的护肤品或化妆品？
# disease=[] symptom=['痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 自觉痒吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '情绪状态', '熬夜', '压力', '焦虑']
# 您提到有熬夜的习惯，这可能影响您的食欲和消化。请问您最近的饮食习惯如何？是否有感到情绪上的压力或焦虑？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况']
# 会吃吗？
# disease=[] symptom=[] medcine=['药物'] surgery=[] body_part=[] medical_check=[] concept=[]
# 糜烂性胃炎的症状包括食道疼痛、吞咽困难、消化不良、腹胀、恶心和呕吐。治疗主要是改善生活方式，调整饮食结构（如戒烟限酒、避免辛辣刺激食物），使用保护胃黏膜的药物，并根据医生建议进行治疗。胃胀可能由多种因素引起，比如胃食管反流病、幽门螺杆菌感染等。请问您目前在服用哪些药物？
# disease=[] symptom=[] medcine=['奥克'] surgery=[] body_part=[] medical_check=[] concept=[]
# 奥克全名是什么？
# disease=[] symptom=['发热', '头痛', '咳嗽'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 根据您的描述，鼻涕带血、鼻塞、流鼻涕和鼻子疼痛可能与鼻炎或鼻窦炎等疾病有关。请问您是否有其他症状，比如发热、头痛或咳嗽？这将有助于我更好地理解您的情况并提供建议。
# disease=[] symptom=['头疼'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有头疼啊？
# disease=[] symptom=['鼻痒', '鼻塞', '流鼻涕', '打喷嚏'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您具体有哪些症状？例如，您是否感到鼻痒、鼻塞、流鼻涕或打喷嚏？
# disease=[] symptom=['喷嚏'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有喷嚏吗？
# disease=[] symptom=['关节疼痛', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！根据您的描述，您可能患有风湿疹，伴随全身长包和瘙痒的症状。为了更好地帮助您，请问您是否有其他相关症状，例如关节疼痛或发热？此外，您之前是否接受过任何治疗？
# disease=[] symptom=['咽喉疼痛', '发烧'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问最近有咽喉疼痛吗？有发烧吗？
# disease=[] symptom=['出血', '分泌物异常', '其他不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您的女友还有其他的症状吗？例如出血、分泌物异常或其他不适？这些信息将有助于我们更好地评估情况。
# disease=[] symptom=['异常流血', '裂伤'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有异常流血。有没有裂伤。
# disease=[] symptom=['咳嗽', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活习惯的变化']
# 您好！根据您描述的嗓子干燥和没食欲的症状，这可能与咽炎或其他疾病有关。请问您最近是否有其他症状，比如咳嗽、发热？同时，您的生活习惯是否有变化？
# disease=[] symptom=['发热', '嗓子疼'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 发热吗？嗓子疼吗？
# disease=[] symptom=['发热', '食欲不振'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '情绪状态']
# 为了更好地理解您的情况，请问您最近是否有其他症状，例如发热、食欲不振或其他不适？同时，您平时的饮食习惯和情绪状态如何？这些信息将有助于我为您提供更准确的建议。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['其它疾病', '饮食情况']
# 有无其它疾病。是否注意饮食。
# disease=[] symptom=['发热', '尿频', '尿急'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 关于附睾隐痛，您可以使用局部热敷来缓解疼痛，这样有助于促进血液循环和减少炎症。同时，保持良好的生活习惯，如注意个人卫生和避免过度劳累也很重要。至于腰酸，建议您多休息、避免过度活动，并使用热敷来缓解疼痛。此外，多饮水有助于排尿和排毒。请问您是否有其他症状，比如发热、尿频或尿急？
# disease=[] symptom=['尿频', '尿急', '尿痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 现在是否有尿频尿急尿痛的情况？
# disease=[] symptom=['发热', '头痛', '视力模糊'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况', '休息情况', '其他症状']
# 您提到的症状包括头晕、恶心和困倦，这可能与多种因素有关。为了更好地理解您的状况，请您提供更多信息，比如您最近的饮食和休息情况，以及是否有其他症状，比如发热、头痛或视力模糊等。
# disease=[] symptom=['其他症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 还有其他症状吗。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['年龄', '病史', '正在服用的药物']
# 为了更好地帮助您，我想了解一下您的具体情况。请问您有多久的时间感到腿部疼痛？是否有其他症状，比如关节僵硬或者麻木？此外，您目前在服用什么药物吗？这些信息将有助于我为您提供更准确的建议。
# disease=[] symptom=[] medcine=['骨质疏松药物'] surgery=[] body_part=[] medical_check=[] concept=[]
# 用什么骨质疏松药物？
# disease=[] symptom=['症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '生活方式']
# 针对您的勃起功能障碍，常见的治疗方法包括服用PDE5抑制剂如西地那非（伟哥），这可以帮助阴茎更好地充血勃起。同时，中医认为可以通过调整饮食（如吃枸杞子、海产品等）、养成良好生活习惯（如充足睡眠和适度运动）来调理肾气不足。请问您目前的症状如何？是否有尝试过其他治疗方法？同时，您平时的饮食和生活方式是怎样的？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['性生活']
# 能不能够完成性生活？
# disease=[] symptom=[] medcine=['用药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 您能否提供更多关于您使用的药物类型和疗程的信息？这将有助于我们更好地理解您的情况并提供建议。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['影响']
# 有影响吗？
# disease=[] symptom=['乳头溢液', '乳房肿块'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['手术经历']
# 乳头内大导管瘤可能与雌激素水平升高有关，并且主要通过手术治疗。请问您是否有任何症状，比如乳头溢液或乳房肿块？同时，您是否考虑过手术治疗？
# disease=[] symptom=['乳头溢液'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 单孔乳头溢液吗？
# disease=[] symptom=['疼痛', '肿胀', '功能受限'] medcine=[] surgery=[] body_part=['手指'] medical_check=[] concept=[]
# 为了更好地帮助您，请您提供一些额外的信息：您的手指疼痛程度如何？这种疼痛是持续的还是间歇性的？有没有伴随其他症状，比如肿胀或功能受限？这些信息将有助于我们为您制定更合适的治疗方案。
# disease=[] symptom=['疼痛严重'] medcine=[] surgery=[] body_part=['手指'] medical_check=[] concept=['发病时间']
# 主要是哪几个手指疼痛严重。做过相关检查吗？什么时候开始这样的？
# disease=[] symptom=['咳嗽', '发热', '胸痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地理解您的情况，请问您最近是否有其他症状，比如咳嗽、发热或者胸痛？这些信息将有助于我们进一步分析您的症状。
# disease=[] symptom=['咳嗽', '喘息'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['病史']
# 有吗？有咳嗽喘息病史吗？
# disease=[] symptom=['大便出血', '腹痛', '体重减轻'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，请问您的大便出血是鲜红色吗？出血的频率如何？是否有其他症状，比如腹痛或者体重减轻？
# disease=[] symptom=['大便稀'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 长期大便是稀的？
# disease=[] symptom=['发热', '胸痛', '乏力'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏史', '吸烟史']
# 为了更好地理解您的症状，请您告诉我是否有发热、胸痛或乏力等症状？另外，您是否有过敏史或吸烟史？这些信息将有助于我们更准确地判断您的病情。
# disease=[] symptom=['痰的颜色', '发热'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 痰什么颜色？有发热吗？
# disease=[] symptom=['疼痛', '瘙痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到在帮宝宝洗有大便的衣服后，手指上出现了水泡。请问您在洗涤过程中是否使用了特定的洗涤剂？此外，您是否有其他症状，比如疼痛或瘙痒？这些信息将有助于更好地理解您的情况。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 其它地方也有吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['生活压力', '情绪状态', '饮食习惯']
# 为了更好地帮助您，请问您最近的生活压力和情绪状态如何？此外，您的饮食习惯是怎样的？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['性生活']
# 你性生活有几次了，有没有。
# disease=[] symptom=['红点', '疼痛', '分泌物', '其他不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到龟头上出现了红点，并且有性行为的经历，这可能与感染有关。为了更好地帮助您，我需要了解更多信息。请问这些红点是否有疼痛感？是否伴有分泌物或其他不适？请您提供更详细的情况，以便我能给您更准确的建议。
# disease=[] symptom=['瘙痒', '疼痛', '不适'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 之前有没有，是否瘙痒疼痛不适。
# disease=[] symptom=['发热', '腹痛'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况']
# 为了更好地帮助您缓解腹泻，请问您最近的饮食习惯是怎样的？有没有其他伴随症状，比如发热、腹痛等？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况']
# 没吃母乳吗？
# disease=[] symptom=['刺痛', '恶心', '呕吐', '腹泻', '便秘'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食情况', '其他症状']
# 为了更好地理解您的症状，您能否提供一些额外的信息？例如，您最近的饮食习惯如何？是否有其他症状，如恶心、呕吐、腹泻或便秘等？
# disease=[] symptom=['恶心', '呕吐', '腹泻'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有恶心、呕吐、腹泻
# disease=[] symptom=['发热', '呕吐'] medcine=['药物'] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！关于您孩子的眼睛红肿和痒的问题，这可能是由于药物引起的过敏反应或其他因素造成的。为了更好地帮助您，我想了解一下孩子在服用药物后的其他症状，比如是否有发热、呕吐等情况？另外，您能告诉我孩子服用的是哪种药物吗？这样我可以为您提供更合适的建议。
# disease=[] symptom=[] medcine=['药'] surgery=[] body_part=[] medical_check=[] concept=[]
# 开的什么药？
# disease=[] symptom=['斜视', '眼睛疼痛', '视力模糊'] medcine=[] surgery=[] body_part=['眼睛'] medical_check=['眼科检查'] concept=['年龄', '其他症状']
# 为了更好地理解您孩子的状况，请问他多大了？除了斜视之外，他有没有其他症状，比如眼睛疼痛或者视力模糊？此外，您是否带他进行过眼科检查？
# disease=[] symptom=['斜视'] medcine=[] surgery=[] body_part=[] medical_check=['验光', '眼底检查'] concept=['发病时间', '检查项目']
# 这样有多长时间了？在当地做过验光，眼底检查吗？需要做检查，确定是斜视还是有视力的问题导致的斜视。
# disease=[] symptom=['红肿', '分泌物', '视力变化'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['过敏源', '眼部疾病史']
# 为了更好地理解您的情况，您能否提供一些额外的信息？例如，您是否有其他症状（如红肿、分泌物、视力变化等），或者您最近是否接触过任何过敏源（如花粉、灰尘等）？此外，您是否有过眼部疾病的病史？
# disease=[] symptom=['分泌物'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 有没有分泌物呢？
# disease=[] symptom=['咳嗽', '发热', '其他不适的症状'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您除了嗓子疼和头晕之外，还有其他症状吗？例如咳嗽、发热或其他不适的症状？
# disease=[] symptom=['不舒服的症状', '发烧'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 都有哪些不舒服的症状？有没有发烧？
# disease=[] symptom=['治疗效果', '不适感'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 请问您在进行光动力疗法后，治疗效果如何？有没有出现任何不适感？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['效果']
# 效果如何？
# disease=[] symptom=['结膜炎', '眼部不适'] medcine=[] surgery=[] body_part=['结膜'] medical_check=[] concept=[]
# 尖锐湿疣主要通过性接触传播，通常不会感染结膜。然而，HPV病毒可能在某些情况下影响结膜。请您告诉我，您是否有其他相关症状，例如结膜炎或其他眼部不适？这样我可以更好地帮助您。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=['眼结膜'] medical_check=[] concept=[]
# 你是说眼结膜吗？
# disease=[] symptom=['小红点', '瘙痒', '疼痛', '出汗'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 为了更好地帮助您，请问这些小红点是否有其他伴随症状，比如瘙痒、疼痛等？此外，您晚上出汗的情况是偶尔发生还是经常出现？
# disease=[] symptom=['痒'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 自觉痒吗？
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食习惯', '其他不适症状']
# 为了更好地理解您的情况，请您提供更多信息，例如您的饮食习惯、是否有其他不适症状，以及您尝试过的任何治疗方法。
# disease=[] symptom=['便意'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=['饮食量']
# 是否没有便意？平时饮食量如何？
# disease=[] symptom=['腹痛', '晕厥'] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 您好！您提到有宫外孕并且出现轻微出血。请问您还有其他症状吗？例如，是否有腹痛、晕厥等？这将有助于我们更好地理解您的状况。
# disease=[] symptom=[] medcine=[] surgery=[] body_part=[] medical_check=[] concept=[]
# 你保什么保

# %%
rr / len(lded)
# Out:
# 6.008159934720522
